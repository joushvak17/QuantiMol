# %%
from chembl_webresource_client.new_client import new_client
import pandas as pd

# %%
target = new_client.target
p_name = input('Enter the name of your target:')
print('Target name: %s' % p_name)
target_query = target.search(p_name)
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
# Target name: EGFR
#                                      cross_references           organism  \
# 0   [{'xref_id': 'Q01279', 'xref_name': None, 'xre...       Mus musculus
# 1                                                  []       Homo sapiens
# 2                                                  []       Homo sapiens
# 3   [{'xref_id': 'P00533', 'xref_name': None, 'xre...       Homo sapiens
# 4                                                  []       Homo sapiens
# 5                                                  []       Homo sapiens
# 6                                                  []       Homo sapiens
# 7                                                  []       Homo sapiens
# 8                                                  []       Homo sapiens
# 9   [{'xref_id': 'P04626', 'xref_name': None, 'xre...       Homo sapiens
# 10  [{'xref_id': 'P06494', 'xref_name': None, 'xre...  Rattus norvegicus
# 11  [{'xref_id': 'Q15303', 'xref_name': None, 'xre...       Homo sapiens
# 12  [{'xref_id': 'P21860', 'xref_name': None, 'xre...       Homo sapiens
# 13                                                 []       Mus musculus
# 14                                                 []       Homo sapiens
# 15                                                 []       Homo sapiens
#
#                                             pref_name  score  \
# 0              Epidermal growth factor receptor erbB1   16.0
# 1                                         EGFR/PPP1CA   16.0
# 2                                            VHL/EGFR   16.0
# 3              Epidermal growth factor receptor erbB1   12.0
# 4                    Epidermal growth factor receptor   11.0
# 5   Protein cereblon/Epidermal growth factor receptor   11.0
# 6   Epidermal growth factor receptor and ErbB2 (HE...   10.0
# 7   MER intracellular domain/EGFR extracellular do...   10.0
# 8                           ErbB-2/ErbB-3 heterodimer   10.0
# 9             Receptor protein-tyrosine kinase erbB-2    9.0
# 10            Receptor protein-tyrosine kinase erbB-2    9.0
# 11            Receptor protein-tyrosine kinase erbB-4    9.0
# 12            Receptor tyrosine-protein kinase erbB-3    9.0
# 13            Receptor tyrosine-protein kinase erbB-2    9.0
# 14                                          FASN/HER2    9.0
# 15  Baculoviral IAP repeat-containing protein 2/Ep...    9.0
#
#     species_group_flag target_chembl_id  \
# 0                False       CHEMBL3608
# 1                False    CHEMBL4523747
# 2                False    CHEMBL4523998
# 3                False        CHEMBL203
# 4                False    CHEMBL2363049
# 5                False    CHEMBL4523680
# 6                False    CHEMBL2111431
# 7                False    CHEMBL3137284
# 8                False    CHEMBL4630723
# 9                False       CHEMBL1824
# 10               False       CHEMBL3848
# 11               False       CHEMBL3009
# 12               False       CHEMBL5838
# 13               False    CHEMBL2311234
# 14               False    CHEMBL4106134
# 15               False    CHEMBL4802031
#
#                                     target_components  \
# 0   [{'accession': 'Q01279', 'component_descriptio...
# 1   [{'accession': 'P00533', 'component_descriptio...
# 2   [{'accession': 'P00533', 'component_descriptio...
# 3   [{'accession': 'P00533', 'component_descriptio...
# 4   [{'accession': 'P04626', 'component_descriptio...
# 5   [{'accession': 'P00533', 'component_descriptio...
# 6   [{'accession': 'P04626', 'component_descriptio...
# 7   [{'accession': 'P00533', 'component_descriptio...
# 8   [{'accession': 'P04626', 'component_descriptio...
# 9   [{'accession': 'P04626', 'component_descriptio...
# 10  [{'accession': 'P06494', 'component_descriptio...
# 11  [{'accession': 'Q15303', 'component_descriptio...
# 12  [{'accession': 'P21860', 'component_descriptio...
# 13  [{'accession': 'P70424', 'component_descriptio...
# 14  [{'accession': 'P04626', 'component_descriptio...
# 15  [{'accession': 'P00533', 'component_descriptio...
#
#                     target_type  tax_id
# 0                SINGLE PROTEIN   10090
# 1   PROTEIN-PROTEIN INTERACTION    9606
# 2   PROTEIN-PROTEIN INTERACTION    9606
# 3                SINGLE PROTEIN    9606
# 4                PROTEIN FAMILY    9606
# 5   PROTEIN-PROTEIN INTERACTION    9606
# 6                PROTEIN FAMILY    9606
# 7              CHIMERIC PROTEIN    9606
# 8               PROTEIN COMPLEX    9606
# 9                SINGLE PROTEIN    9606
# 10               SINGLE PROTEIN   10116
# 11               SINGLE PROTEIN    9606
# 12               SINGLE PROTEIN    9606
# 13               SINGLE PROTEIN   10090
# 14              PROTEIN COMPLEX    9606
# 15  PROTEIN-PROTEIN INTERACTION    9606

# %%
selected_target = targets.target_chembl_id[3]
selected_target
# Out:
# 'CHEMBL203'

# %%
activity = new_client.activity
activity_query = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")
activities = pd.DataFrame.from_dict(activity_query)
activities
# Out:
#                                              action_type activity_comment  \
# 0                                                   None             None
# 1                                                   None             None
# 2                                                   None             None
# 3                                                   None             None
# 4                                                   None             None
# ...                                                  ...              ...
# 17281  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 17282  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 17283  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 17284  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 17285  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#        activity_id                                activity_properties  \
# 0            32260                                                 []
# 1            32263                                                 []
# 2            32265                                                 []
# 3            32267                                                 []
# 4            32270                                                 []
# ...            ...                                                ...
# 17281     25105762                                                 []
# 17282     25105763                                                 []
# 17283     25105764                                                 []
# 17284     25106404  [{'comments': None, 'relation': '=', 'result_f...
# 17285     25109727  [{'comments': None, 'relation': '=', 'result_f...
#
#       assay_chembl_id                                  assay_description  \
# 0        CHEMBL674637  Inhibitory activity towards tyrosine phosphory...
# 1        CHEMBL621151  Inhibition of autophosphorylation of human epi...
# 2        CHEMBL615325  Inhibition of ligand-induced proliferation in ...
# 3        CHEMBL674637  Inhibitory activity towards tyrosine phosphory...
# 4        CHEMBL621151  Inhibition of autophosphorylation of human epi...
# ...               ...                                                ...
# 17281   CHEMBL5263207  Inhibition of wild type EGFR (unknown origin) ...
# 17282   CHEMBL5263207  Inhibition of wild type EGFR (unknown origin) ...
# 17283   CHEMBL5263207  Inhibition of wild type EGFR (unknown origin) ...
# 17284   CHEMBL5263429  Inhibition of EGFR (unknown origin) using (Glu...
# 17285   CHEMBL5264736  Inhibition of human EGFR L858R mutant (669 to ...
#
#       assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0              B                    None                   None  BAO_0000190
# 1              F                    None                   None  BAO_0000190
# 2              F                    None                   None  BAO_0000190
# 3              B                    None                   None  BAO_0000190
# 4              F                    None                   None  BAO_0000190
# ...          ...                     ...                    ...          ...
# 17281          B                    None                   None  BAO_0000190
# 17282          B                    None                   None  BAO_0000190
# 17283          B                    None                   None  BAO_0000190
# 17284          B                    None                   None  BAO_0000190
# 17285          B                  P00533                  L858R  BAO_0000190
#
#        ... target_organism                        target_pref_name  \
# 0      ...    Homo sapiens  Epidermal growth factor receptor erbB1
# 1      ...    Homo sapiens  Epidermal growth factor receptor erbB1
# 2      ...    Homo sapiens  Epidermal growth factor receptor erbB1
# 3      ...    Homo sapiens  Epidermal growth factor receptor erbB1
# 4      ...    Homo sapiens  Epidermal growth factor receptor erbB1
# ...    ...             ...                                     ...
# 17281  ...    Homo sapiens  Epidermal growth factor receptor erbB1
# 17282  ...    Homo sapiens  Epidermal growth factor receptor erbB1
# 17283  ...    Homo sapiens  Epidermal growth factor receptor erbB1
# 17284  ...    Homo sapiens  Epidermal growth factor receptor erbB1
# 17285  ...    Homo sapiens  Epidermal growth factor receptor erbB1
#
#       target_tax_id text_value  toid  type units    uo_units upper_value  \
# 0              9606       None  None  IC50    uM  UO_0000065        None
# 1              9606       None  None  IC50    uM  UO_0000065        None
# 2              9606       None  None  IC50    uM  UO_0000065        None
# 3              9606       None  None  IC50    uM  UO_0000065        None
# 4              9606       None  None  IC50    uM  UO_0000065        None
# ...             ...        ...   ...   ...   ...         ...         ...
# 17281          9606       None  None  IC50    nM  UO_0000065        None
# 17282          9606       None  None  IC50    nM  UO_0000065        None
# 17283          9606       None  None  IC50    nM  UO_0000065        None
# 17284          9606       None  None  IC50    uM  UO_0000065        None
# 17285          9606       None  None  IC50    nM  UO_0000065        None
#
#        value
# 0      0.041
# 1        0.3
# 2       7.82
# 3       0.17
# 4       0.04
# ...      ...
# 17281  202.5
# 17282   26.9
# 17283  228.9
# 17284   7.67
# 17285   0.85
#
# [17286 rows x 46 columns]

# %%
list(activities.columns)
# Out:
# ['action_type',
#  'activity_comment',
#  'activity_id',
#  'activity_properties',
#  'assay_chembl_id',
#  'assay_description',
#  'assay_type',
#  'assay_variant_accession',
#  'assay_variant_mutation',
#  'bao_endpoint',
#  'bao_format',
#  'bao_label',
#  'canonical_smiles',
#  'data_validity_comment',
#  'data_validity_description',
#  'document_chembl_id',
#  'document_journal',
#  'document_year',
#  'ligand_efficiency',
#  'molecule_chembl_id',
#  'molecule_pref_name',
#  'parent_molecule_chembl_id',
#  'pchembl_value',
#  'potential_duplicate',
#  'qudt_units',
#  'record_id',
#  'relation',
#  'src_id',
#  'standard_flag',
#  'standard_relation',
#  'standard_text_value',
#  'standard_type',
#  'standard_units',
#  'standard_upper_value',
#  'standard_value',
#  'target_chembl_id',
#  'target_organism',
#  'target_pref_name',
#  'target_tax_id',
#  'text_value',
#  'toid',
#  'type',
#  'units',
#  'uo_units',
#  'upper_value',
#  'value']

# %%
activities = activities[activities.standard_value.notna()]
activities = activities[activities.canonical_smiles.notna()]
activities
# Out:
#                                              action_type activity_comment  \
# 0                                                   None             None
# 1                                                   None             None
# 2                                                   None             None
# 3                                                   None             None
# 4                                                   None             None
# ...                                                  ...              ...
# 17281  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 17282  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 17283  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 17284  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 17285  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#        activity_id                                activity_properties  \
# 0            32260                                                 []
# 1            32263                                                 []
# 2            32265                                                 []
# 3            32267                                                 []
# 4            32270                                                 []
# ...            ...                                                ...
# 17281     25105762                                                 []
# 17282     25105763                                                 []
# 17283     25105764                                                 []
# 17284     25106404  [{'comments': None, 'relation': '=', 'result_f...
# 17285     25109727  [{'comments': None, 'relation': '=', 'result_f...
#
#       assay_chembl_id                                  assay_description  \
# 0        CHEMBL674637  Inhibitory activity towards tyrosine phosphory...
# 1        CHEMBL621151  Inhibition of autophosphorylation of human epi...
# 2        CHEMBL615325  Inhibition of ligand-induced proliferation in ...
# 3        CHEMBL674637  Inhibitory activity towards tyrosine phosphory...
# 4        CHEMBL621151  Inhibition of autophosphorylation of human epi...
# ...               ...                                                ...
# 17281   CHEMBL5263207  Inhibition of wild type EGFR (unknown origin) ...
# 17282   CHEMBL5263207  Inhibition of wild type EGFR (unknown origin) ...
# 17283   CHEMBL5263207  Inhibition of wild type EGFR (unknown origin) ...
# 17284   CHEMBL5263429  Inhibition of EGFR (unknown origin) using (Glu...
# 17285   CHEMBL5264736  Inhibition of human EGFR L858R mutant (669 to ...
#
#       assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0              B                    None                   None  BAO_0000190
# 1              F                    None                   None  BAO_0000190
# 2              F                    None                   None  BAO_0000190
# 3              B                    None                   None  BAO_0000190
# 4              F                    None                   None  BAO_0000190
# ...          ...                     ...                    ...          ...
# 17281          B                    None                   None  BAO_0000190
# 17282          B                    None                   None  BAO_0000190
# 17283          B                    None                   None  BAO_0000190
# 17284          B                    None                   None  BAO_0000190
# 17285          B                  P00533                  L858R  BAO_0000190
#
#        ... target_organism                        target_pref_name  \
# 0      ...    Homo sapiens  Epidermal growth factor receptor erbB1
# 1      ...    Homo sapiens  Epidermal growth factor receptor erbB1
# 2      ...    Homo sapiens  Epidermal growth factor receptor erbB1
# 3      ...    Homo sapiens  Epidermal growth factor receptor erbB1
# 4      ...    Homo sapiens  Epidermal growth factor receptor erbB1
# ...    ...             ...                                     ...
# 17281  ...    Homo sapiens  Epidermal growth factor receptor erbB1
# 17282  ...    Homo sapiens  Epidermal growth factor receptor erbB1
# 17283  ...    Homo sapiens  Epidermal growth factor receptor erbB1
# 17284  ...    Homo sapiens  Epidermal growth factor receptor erbB1
# 17285  ...    Homo sapiens  Epidermal growth factor receptor erbB1
#
#       target_tax_id text_value  toid  type units    uo_units upper_value  \
# 0              9606       None  None  IC50    uM  UO_0000065        None
# 1              9606       None  None  IC50    uM  UO_0000065        None
# 2              9606       None  None  IC50    uM  UO_0000065        None
# 3              9606       None  None  IC50    uM  UO_0000065        None
# 4              9606       None  None  IC50    uM  UO_0000065        None
# ...             ...        ...   ...   ...   ...         ...         ...
# 17281          9606       None  None  IC50    nM  UO_0000065        None
# 17282          9606       None  None  IC50    nM  UO_0000065        None
# 17283          9606       None  None  IC50    nM  UO_0000065        None
# 17284          9606       None  None  IC50    uM  UO_0000065        None
# 17285          9606       None  None  IC50    nM  UO_0000065        None
#
#        value
# 0      0.041
# 1        0.3
# 2       7.82
# 3       0.17
# 4       0.04
# ...      ...
# 17281  202.5
# 17282   26.9
# 17283  228.9
# 17284   7.67
# 17285   0.85
#
# [15900 rows x 46 columns]

# %%
activities = activities.drop_duplicates(['canonical_smiles'])
activities
# Out:
#                                              action_type activity_comment  \
# 0                                                   None             None
# 3                                                   None             None
# 6                                                   None             None
# 7                                                   None             None
# 8                                                   None             None
# ...                                                  ...              ...
# 17238  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 17239  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 17240  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 17241  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 17242  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#        activity_id activity_properties assay_chembl_id  \
# 0            32260                  []    CHEMBL674637
# 3            32267                  []    CHEMBL674637
# 6            32680                  []    CHEMBL677833
# 7            32770                  []    CHEMBL674643
# 8            32772                  []    CHEMBL674643
# ...            ...                 ...             ...
# 17238     25105719                  []   CHEMBL5263205
# 17239     25105720                  []   CHEMBL5263205
# 17240     25105721                  []   CHEMBL5263205
# 17241     25105722                  []   CHEMBL5263205
# 17242     25105723                  []   CHEMBL5263205
#
#                                        assay_description assay_type  \
# 0      Inhibitory activity towards tyrosine phosphory...          B
# 3      Inhibitory activity towards tyrosine phosphory...          B
# 6      In vitro inhibition of Epidermal growth factor...          B
# 7      Inhibitory concentration of EGF dependent auto...          B
# 8      Inhibitory concentration of EGF dependent auto...          B
# ...                                                  ...        ...
# 17238  Inhibition of EGFR L858R/T790M mutant (unknown...          B
# 17239  Inhibition of EGFR L858R/T790M mutant (unknown...          B
# 17240  Inhibition of EGFR L858R/T790M mutant (unknown...          B
# 17241  Inhibition of EGFR L858R/T790M mutant (unknown...          B
# 17242  Inhibition of EGFR L858R/T790M mutant (unknown...          B
#
#       assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0                        None                   None  BAO_0000190  ...
# 3                        None                   None  BAO_0000190  ...
# 6                        None                   None  BAO_0000190  ...
# 7                        None                   None  BAO_0000190  ...
# 8                        None                   None  BAO_0000190  ...
# ...                       ...                    ...          ...  ...
# 17238                  P00533            L858R,T790M  BAO_0000190  ...
# 17239                  P00533            L858R,T790M  BAO_0000190  ...
# 17240                  P00533            L858R,T790M  BAO_0000190  ...
# 17241                  P00533            L858R,T790M  BAO_0000190  ...
# 17242                  P00533            L858R,T790M  BAO_0000190  ...
#
#       target_organism                        target_pref_name target_tax_id  \
# 0        Homo sapiens  Epidermal growth factor receptor erbB1          9606
# 3        Homo sapiens  Epidermal growth factor receptor erbB1          9606
# 6        Homo sapiens  Epidermal growth factor receptor erbB1          9606
# 7        Homo sapiens  Epidermal growth factor receptor erbB1          9606
# 8        Homo sapiens  Epidermal growth factor receptor erbB1          9606
# ...               ...                                     ...           ...
# 17238    Homo sapiens  Epidermal growth factor receptor erbB1          9606
# 17239    Homo sapiens  Epidermal growth factor receptor erbB1          9606
# 17240    Homo sapiens  Epidermal growth factor receptor erbB1          9606
# 17241    Homo sapiens  Epidermal growth factor receptor erbB1          9606
# 17242    Homo sapiens  Epidermal growth factor receptor erbB1          9606
#
#       text_value  toid  type units    uo_units upper_value   value
# 0           None  None  IC50    uM  UO_0000065        None   0.041
# 3           None  None  IC50    uM  UO_0000065        None    0.17
# 6           None  None  IC50    uM  UO_0000065        None     9.3
# 7           None  None  IC50    uM  UO_0000065        None   500.0
# 8           None  None  IC50    uM  UO_0000065        None  3000.0
# ...          ...   ...   ...   ...         ...         ...     ...
# 17238       None  None  IC50    nM  UO_0000065        None     4.1
# 17239       None  None  IC50    nM  UO_0000065        None     0.6
# 17240       None  None  IC50    nM  UO_0000065        None    27.7
# 17241       None  None  IC50    nM  UO_0000065        None     3.2
# 17242       None  None  IC50    nM  UO_0000065        None     8.4
#
# [9794 rows x 46 columns]

# %%
imp_col = ['molecule_chembl_id', 'canonical_smiles', 'standard_value']
activities = activities[imp_col]
activities
# Out:
#       molecule_chembl_id                                   canonical_smiles  \
# 0            CHEMBL68920  Cc1cc(C)c(/C=C2\C(=O)Nc3ncnc(Nc4ccc(F)c(Cl)c4)...
# 3            CHEMBL69960  Cc1cc(C(=O)N2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(N...
# 6           CHEMBL137635        CN(c1ccccc1)c1ncnc2ccc(N/N=N/Cc3ccccn3)cc12
# 7           CHEMBL306988             CC(=C(C#N)C#N)c1ccc(NC(=O)CCC(=O)O)cc1
# 8            CHEMBL66879                             O=C(O)/C=C/c1ccc(O)cc1
# ...                  ...                                                ...
# 17238      CHEMBL5270334  C=CC(=O)Nc1cc(Nc2ncc(Br)c(Nc3ccc4ccn(C)c4c3)n2...
# 17239      CHEMBL5271151  C=CC(=O)Nc1cc(Nc2ncc(Br)c(Nc3ccc4c(c3)CCC4)n2)...
# 17240      CHEMBL5265870  C=CC(=O)Nc1cc(Nc2ncc(Br)c(Nc3ccc4c(c3)CCC4)n2)...
# 17241      CHEMBL5269747  C=CC(=O)Nc1cc(Nc2ncc(Br)c(Nc3ccc4c(c3)CCC4)n2)...
# 17242      CHEMBL5286080  C=CC(=O)Nc1cc(Nc2nccc(Nc3ccc4c(ccn4C)c3)n2)c(O...
#
#       standard_value
# 0               41.0
# 3              170.0
# 6             9300.0
# 7           500000.0
# 8          3000000.0
# ...              ...
# 17238            4.1
# 17239            0.6
# 17240           27.7
# 17241            3.2
# 17242            8.4
#
# [9794 rows x 3 columns]

# %%
activities_copy = activities.copy()

activities_copy['standard_value'] = activities_copy['standard_value'].astype(float)

activities_copy = activities_copy[~activities_copy['standard_value'].between(100, 1000)]

threshold = []
for i in activities_copy.standard_value:
    if i >= 1000:
        threshold.append('inactive')
    else:
        threshold.append('active')

activities_copy.loc[:, 'class'] = threshold
activities_copy
# Out:
#       molecule_chembl_id                                   canonical_smiles  \
# 0            CHEMBL68920  Cc1cc(C)c(/C=C2\C(=O)Nc3ncnc(Nc4ccc(F)c(Cl)c4)...
# 6           CHEMBL137635        CN(c1ccccc1)c1ncnc2ccc(N/N=N/Cc3ccccn3)cc12
# 7           CHEMBL306988             CC(=C(C#N)C#N)c1ccc(NC(=O)CCC(=O)O)cc1
# 8            CHEMBL66879                             O=C(O)/C=C/c1ccc(O)cc1
# 9            CHEMBL77085                 N#CC(C#N)=Cc1cc(O)ccc1[N+](=O)[O-]
# ...                  ...                                                ...
# 17238      CHEMBL5270334  C=CC(=O)Nc1cc(Nc2ncc(Br)c(Nc3ccc4ccn(C)c4c3)n2...
# 17239      CHEMBL5271151  C=CC(=O)Nc1cc(Nc2ncc(Br)c(Nc3ccc4c(c3)CCC4)n2)...
# 17240      CHEMBL5265870  C=CC(=O)Nc1cc(Nc2ncc(Br)c(Nc3ccc4c(c3)CCC4)n2)...
# 17241      CHEMBL5269747  C=CC(=O)Nc1cc(Nc2ncc(Br)c(Nc3ccc4c(c3)CCC4)n2)...
# 17242      CHEMBL5286080  C=CC(=O)Nc1cc(Nc2nccc(Nc3ccc4c(ccn4C)c3)n2)c(O...
#
#        standard_value     class
# 0                41.0    active
# 6              9300.0  inactive
# 7            500000.0  inactive
# 8           3000000.0  inactive
# 9             96000.0  inactive
# ...               ...       ...
# 17238             4.1    active
# 17239             0.6    active
# 17240            27.7    active
# 17241             3.2    active
# 17242             8.4    active
#
# [7334 rows x 4 columns]

# %%
activities_copy.to_csv('EGFR_Data_Preprocessed.csv', index=False)
