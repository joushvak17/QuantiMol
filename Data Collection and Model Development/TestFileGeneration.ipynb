# %%
from chembl_webresource_client.new_client import new_client
import pandas as pd

# %%
target = new_client.target
p_name = "EGFR"
target_query = target.search(p_name)
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                      cross_references           organism  \
# 0   [{'xref_id': 'Q01279', 'xref_name': None, 'xre...       Mus musculus
# 1                                                  []       Homo sapiens
# 2                                                  []       Homo sapiens
# 3   [{'xref_id': 'P00533', 'xref_name': None, 'xre...       Homo sapiens
# 4                                                  []       Homo sapiens
# 5                                                  []       Homo sapiens
# 6                                                  []       Homo sapiens
# 7                                                  []       Homo sapiens
# 8                                                  []       Homo sapiens
# 9   [{'xref_id': 'P04626', 'xref_name': None, 'xre...       Homo sapiens
# 10  [{'xref_id': 'P06494', 'xref_name': None, 'xre...  Rattus norvegicus
# 11  [{'xref_id': 'Q15303', 'xref_name': None, 'xre...       Homo sapiens
# ...

# %%
selected_target = targets.target_chembl_id[9]

# %%
activity = new_client.activity
activity_query = activity.filter(target_chembl_id=selected_target).filter(standard_type='IC50')
activities = pd.DataFrame.from_dict(activity_query)
activities.head()
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None        32264                  []
# 1        None             None        32266                  []
# 2        None             None        32271                  []
# 3        None             None        32273                  []
# 4        None             None        47937                  []
#
#   assay_chembl_id                                  assay_description  \
# 0    CHEMBL845865  Inhibition of autophosphorylation of human Her...
# 1    CHEMBL615491  Inhibition of ligand induced proliferation in ...
# 2    CHEMBL683802  Inhibition of autophosphorylation of human Her...
# 3    CHEMBL615491  Inhibition of ligand induced proliferation in ...
# 4    CHEMBL683802  Inhibition of autophosphorylation of human Her...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          F                    None                   None  BAO_0000190  ...
# ...

# %%
list(activities.columns)
# Out:
# ['action_type',
#  'activity_comment',
#  'activity_id',
#  'activity_properties',
#  'assay_chembl_id',
#  'assay_description',
#  'assay_type',
#  'assay_variant_accession',
#  'assay_variant_mutation',
#  'bao_endpoint',
#  'bao_format',
#  'bao_label',
#  'canonical_smiles',
#  'data_validity_comment',
#  'data_validity_description',
#  'document_chembl_id',
#  'document_journal',
#  'document_year',
#  'ligand_efficiency',
#  'molecule_chembl_id',
#  'molecule_pref_name',
#  'parent_molecule_chembl_id',
#  'pchembl_value',
#  'potential_duplicate',
#  'qudt_units',
#  'record_id',
#  'relation',
#  'src_id',
#  'standard_flag',
#  'standard_relation',
#  'standard_text_value',
#  'standard_type',
#  'standard_units',
#  'standard_upper_value',
#  'standard_value',
#  'target_chembl_id',
#  'target_organism',
#  'target_pref_name',
#  'target_tax_id',
#  'text_value',
#  'toid',
#  'type',
#  'units',
#  'uo_units',
#  'upper_value',
#  'value']

# %%
activities = activities[activities.canonical_smiles.notna()]
activities
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 4092  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 4093  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 4094  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 4095  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 4096  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#       activity_id activity_properties assay_chembl_id  \
# ...

# %%
activities = activities.drop_duplicates(['canonical_smiles'])
activities
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 2                                                  None             None
# 4                                                  None             None
# 6                                                  None             None
# 8                                                  None             None
# ...                                                 ...              ...
# 4090                                               None             None
# 4091                                               None             None
# 4092  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 4095  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 4096  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#       activity_id activity_properties assay_chembl_id  \
# ...

# %%
activities = activities['canonical_smiles']
activities
# Out:
# 0       Cc1cc(C)c(/C=C2\C(=O)Nc3ncnc(Nc4ccc(F)c(Cl)c4)...
# 2       Cc1cc(C(=O)N2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(N...
# 4       Cc1cc(C(=O)N2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(N...
# 6       Cc1cc(C(=O)N2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(N...
# 8       Cc1cc(C(=O)NCCN2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncn...
#                               ...
# 4090    Nc1nccc(Oc2ccc3c(C(=O)Nc4cccc(C(F)(F)F)c4)cccc...
# 4091    O=C(Nc1cccc(C(F)(F)F)c1)c1cccc2cc(Oc3cc(CO)ncn...
# 4092                    COc1cc2ncnc(NCCOc3ccccc3F)c2cc1OC
# 4095    C=CC(=O)N1CCC(Oc2cc3c(Nc4ccc(Cl)c(Cl)c4F)ncnc3...
# 4096    C=CC(=O)N1CCC(Oc2cc3c(Nc4cccc(Cl)c4F)ncnc3cc2O...
# Name: canonical_smiles, Length: 3593, dtype: object

# %%
print(activities.count())
# Out:
# 3593

# %%
activities.to_csv('EGFR_Data_TestFile.csv', index=False)
