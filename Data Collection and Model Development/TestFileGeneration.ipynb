# %%
from chembl_webresource_client.new_client import new_client
import pandas as pd

# %%
target = new_client.target
p_name = "EGFR"
target_query = target.search(p_name)
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                      cross_references           organism  \
# 0   [{'xref_id': 'Q01279', 'xref_name': None, 'xre...       Mus musculus
# 1                                                  []       Homo sapiens
# 2                                                  []       Homo sapiens
# 3   [{'xref_id': 'P00533', 'xref_name': None, 'xre...       Homo sapiens
# 4                                                  []       Homo sapiens
# 5                                                  []       Homo sapiens
# 6                                                  []       Homo sapiens
# 7                                                  []       Homo sapiens
# 8                                                  []       Homo sapiens
# 9   [{'xref_id': 'P04626', 'xref_name': None, 'xre...       Homo sapiens
# 10  [{'xref_id': 'P06494', 'xref_name': None, 'xre...  Rattus norvegicus
# 11  [{'xref_id': 'Q15303', 'xref_name': None, 'xre...       Homo sapiens
# 12  [{'xref_id': 'P21860', 'xref_name': None, 'xre...       Homo sapiens
# 13                                                 []       Mus musculus
# 14                                                 []       Homo sapiens
# 15                                                 []       Homo sapiens
#
#                                             pref_name  score  \
# 0              Epidermal growth factor receptor erbB1   16.0
# 1                                         EGFR/PPP1CA   16.0
# 2                                            VHL/EGFR   16.0
# 3              Epidermal growth factor receptor erbB1   12.0
# 4   Protein cereblon/Epidermal growth factor receptor   12.0
# 5                    Epidermal growth factor receptor   11.0
# 6   Epidermal growth factor receptor and ErbB2 (HE...   10.0
# 7   MER intracellular domain/EGFR extracellular do...   10.0
# 8                           ErbB-2/ErbB-3 heterodimer   10.0
# 9             Receptor protein-tyrosine kinase erbB-2    9.0
# 10            Receptor protein-tyrosine kinase erbB-2    9.0
# 11            Receptor protein-tyrosine kinase erbB-4    9.0
# 12            Receptor tyrosine-protein kinase erbB-3    9.0
# 13            Receptor tyrosine-protein kinase erbB-2    9.0
# 14                                          FASN/HER2    9.0
# 15  Baculoviral IAP repeat-containing protein 2/Ep...    9.0
#
#     species_group_flag target_chembl_id  \
# 0                False       CHEMBL3608
# 1                False    CHEMBL4523747
# 2                False    CHEMBL4523998
# 3                False        CHEMBL203
# 4                False    CHEMBL4523680
# 5                False    CHEMBL2363049
# 6                False    CHEMBL2111431
# 7                False    CHEMBL3137284
# 8                False    CHEMBL4630723
# 9                False       CHEMBL1824
# 10               False       CHEMBL3848
# 11               False       CHEMBL3009
# 12               False       CHEMBL5838
# 13               False    CHEMBL2311234
# 14               False    CHEMBL4106134
# 15               False    CHEMBL4802031
#
#                                     target_components  \
# 0   [{'accession': 'Q01279', 'component_descriptio...
# 1   [{'accession': 'P00533', 'component_descriptio...
# 2   [{'accession': 'P00533', 'component_descriptio...
# 3   [{'accession': 'P00533', 'component_descriptio...
# 4   [{'accession': 'P00533', 'component_descriptio...
# 5   [{'accession': 'P04626', 'component_descriptio...
# 6   [{'accession': 'P04626', 'component_descriptio...
# 7   [{'accession': 'P00533', 'component_descriptio...
# 8   [{'accession': 'P04626', 'component_descriptio...
# 9   [{'accession': 'P04626', 'component_descriptio...
# 10  [{'accession': 'P06494', 'component_descriptio...
# 11  [{'accession': 'Q15303', 'component_descriptio...
# 12  [{'accession': 'P21860', 'component_descriptio...
# 13  [{'accession': 'P70424', 'component_descriptio...
# 14  [{'accession': 'P04626', 'component_descriptio...
# 15  [{'accession': 'P00533', 'component_descriptio...
#
#                     target_type  tax_id
# 0                SINGLE PROTEIN   10090
# 1   PROTEIN-PROTEIN INTERACTION    9606
# 2   PROTEIN-PROTEIN INTERACTION    9606
# 3                SINGLE PROTEIN    9606
# 4   PROTEIN-PROTEIN INTERACTION    9606
# 5                PROTEIN FAMILY    9606
# 6                PROTEIN FAMILY    9606
# 7              CHIMERIC PROTEIN    9606
# 8               PROTEIN COMPLEX    9606
# 9                SINGLE PROTEIN    9606
# 10               SINGLE PROTEIN   10116
# 11               SINGLE PROTEIN    9606
# 12               SINGLE PROTEIN    9606
# 13               SINGLE PROTEIN   10090
# 14              PROTEIN COMPLEX    9606
# 15  PROTEIN-PROTEIN INTERACTION    9606

# %%
selected_target = targets.target_chembl_id[9]

# %%
activity = new_client.activity
activity_query = activity.filter(target_chembl_id=selected_target).filter(standard_type='IC50')
activities = pd.DataFrame.from_dict(activity_query)
activities.head()
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None        32264                  []
# 1        None             None        32266                  []
# 2        None             None        32271                  []
# 3        None             None        32273                  []
# 4        None             None        47937                  []
#
#   assay_chembl_id                                  assay_description  \
# 0    CHEMBL845865  Inhibition of autophosphorylation of human Her...
# 1    CHEMBL615491  Inhibition of ligand induced proliferation in ...
# 2    CHEMBL683802  Inhibition of autophosphorylation of human Her...
# 3    CHEMBL615491  Inhibition of ligand induced proliferation in ...
# 4    CHEMBL683802  Inhibition of autophosphorylation of human Her...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          F                    None                   None  BAO_0000190  ...
# 1          F                    None                   None  BAO_0000190  ...
# 2          F                    None                   None  BAO_0000190  ...
# 3          F                    None                   None  BAO_0000190  ...
# 4          F                    None                   None  BAO_0000190  ...
#
#   target_organism                         target_pref_name target_tax_id  \
# 0    Homo sapiens  Receptor protein-tyrosine kinase erbB-2          9606
# 1    Homo sapiens  Receptor protein-tyrosine kinase erbB-2          9606
# 2    Homo sapiens  Receptor protein-tyrosine kinase erbB-2          9606
# 3    Homo sapiens  Receptor protein-tyrosine kinase erbB-2          9606
# 4    Homo sapiens  Receptor protein-tyrosine kinase erbB-2          9606
#
#   text_value  toid  type units    uo_units upper_value value
# 0       None  None  IC50    uM  UO_0000065        None   0.3
# 1       None  None  IC50    uM  UO_0000065        None   2.5
# 2       None  None  IC50    uM  UO_0000065        None   0.4
# 3       None  None  IC50    uM  UO_0000065        None  1.21
# 4       None  None  IC50    uM  UO_0000065        None   0.1
#
# [5 rows x 46 columns]

# %%
list(activities.columns)
# Out:
# ['action_type',
#  'activity_comment',
#  'activity_id',
#  'activity_properties',
#  'assay_chembl_id',
#  'assay_description',
#  'assay_type',
#  'assay_variant_accession',
#  'assay_variant_mutation',
#  'bao_endpoint',
#  'bao_format',
#  'bao_label',
#  'canonical_smiles',
#  'data_validity_comment',
#  'data_validity_description',
#  'document_chembl_id',
#  'document_journal',
#  'document_year',
#  'ligand_efficiency',
#  'molecule_chembl_id',
#  'molecule_pref_name',
#  'parent_molecule_chembl_id',
#  'pchembl_value',
#  'potential_duplicate',
#  'qudt_units',
#  'record_id',
#  'relation',
#  'src_id',
#  'standard_flag',
#  'standard_relation',
#  'standard_text_value',
#  'standard_type',
#  'standard_units',
#  'standard_upper_value',
#  'standard_value',
#  'target_chembl_id',
#  'target_organism',
#  'target_pref_name',
#  'target_tax_id',
#  'text_value',
#  'toid',
#  'type',
#  'units',
#  'uo_units',
#  'upper_value',
#  'value']

# %%
activities = activities[activities.canonical_smiles.notna()]
activities
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 4067  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 4068  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 4069  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 4070  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 4071  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#       activity_id                                activity_properties  \
# 0           32264                                                 []
# 1           32266                                                 []
# 2           32271                                                 []
# 3           32273                                                 []
# 4           47937                                                 []
# ...           ...                                                ...
# 4067     24958832                                                 []
# 4068     24959145                                                 []
# 4069     24962762                                                 []
# 4070     24962907  [{'comments': None, 'relation': '=', 'result_f...
# 4071     24962908  [{'comments': None, 'relation': '=', 'result_f...
#
#      assay_chembl_id                                  assay_description  \
# 0       CHEMBL845865  Inhibition of autophosphorylation of human Her...
# 1       CHEMBL615491  Inhibition of ligand induced proliferation in ...
# 2       CHEMBL683802  Inhibition of autophosphorylation of human Her...
# 3       CHEMBL615491  Inhibition of ligand induced proliferation in ...
# 4       CHEMBL683802  Inhibition of autophosphorylation of human Her...
# ...              ...                                                ...
# 4067   CHEMBL5215095                Inhibition of HER2 (unknown origin)
# 4068   CHEMBL5215236                Inhibition of HER2 (unknown origin)
# 4069   CHEMBL5216230  Inhibition of Her2 in human MCF7 cells by SDS-...
# 4070   CHEMBL5216307  Inhibition of HER2 (unknown origin) incubated ...
# 4071   CHEMBL5216307  Inhibition of HER2 (unknown origin) incubated ...
#
#      assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0             F                    None                   None  BAO_0000190
# 1             F                    None                   None  BAO_0000190
# 2             F                    None                   None  BAO_0000190
# 3             F                    None                   None  BAO_0000190
# 4             F                    None                   None  BAO_0000190
# ...         ...                     ...                    ...          ...
# 4067          B                    None                   None  BAO_0000190
# 4068          B                    None                   None  BAO_0000190
# 4069          B                    None                   None  BAO_0000190
# 4070          B                    None                   None  BAO_0000190
# 4071          B                    None                   None  BAO_0000190
#
#       ... target_organism                         target_pref_name  \
# 0     ...    Homo sapiens  Receptor protein-tyrosine kinase erbB-2
# 1     ...    Homo sapiens  Receptor protein-tyrosine kinase erbB-2
# 2     ...    Homo sapiens  Receptor protein-tyrosine kinase erbB-2
# 3     ...    Homo sapiens  Receptor protein-tyrosine kinase erbB-2
# 4     ...    Homo sapiens  Receptor protein-tyrosine kinase erbB-2
# ...   ...             ...                                      ...
# 4067  ...    Homo sapiens  Receptor protein-tyrosine kinase erbB-2
# 4068  ...    Homo sapiens  Receptor protein-tyrosine kinase erbB-2
# 4069  ...    Homo sapiens  Receptor protein-tyrosine kinase erbB-2
# 4070  ...    Homo sapiens  Receptor protein-tyrosine kinase erbB-2
# 4071  ...    Homo sapiens  Receptor protein-tyrosine kinase erbB-2
#
#      target_tax_id text_value  toid  type units    uo_units upper_value value
# 0             9606       None  None  IC50    uM  UO_0000065        None   0.3
# 1             9606       None  None  IC50    uM  UO_0000065        None   2.5
# 2             9606       None  None  IC50    uM  UO_0000065        None   0.4
# 3             9606       None  None  IC50    uM  UO_0000065        None  1.21
# 4             9606       None  None  IC50    uM  UO_0000065        None   0.1
# ...            ...        ...   ...   ...   ...         ...         ...   ...
# 4067          9606       None  None  IC50    uM  UO_0000065        None  0.12
# 4068          9606       None  None  IC50    nM  UO_0000065        None  29.2
# 4069          9606       None  None  IC50    uM  UO_0000065        None  40.0
# 4070          9606       None  None  IC50    nM  UO_0000065        None  0.14
# 4071          9606       None  None  IC50    nM  UO_0000065        None  0.06
#
# [4040 rows x 46 columns]

# %%
activities = activities.drop_duplicates(['canonical_smiles'])
activities
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 2                                                  None             None
# 4                                                  None             None
# 6                                                  None             None
# 8                                                  None             None
# ...                                                 ...              ...
# 4040  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 4056                                               None             None
# 4057                                               None             None
# 4058  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 4070  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#       activity_id                                activity_properties  \
# 0           32264                                                 []
# 2           32271                                                 []
# 4           47937                                                 []
# 6           49330                                                 []
# 8           50672                                                 []
# ...           ...                                                ...
# 4040     24907640  [{'comments': None, 'relation': '=', 'result_f...
# 4056     24918282                                                 []
# 4057     24918283                                                 []
# 4058     24953726  [{'comments': None, 'relation': None, 'result_...
# 4070     24962907  [{'comments': None, 'relation': '=', 'result_f...
#
#      assay_chembl_id                                  assay_description  \
# 0       CHEMBL845865  Inhibition of autophosphorylation of human Her...
# 2       CHEMBL683802  Inhibition of autophosphorylation of human Her...
# 4       CHEMBL683802  Inhibition of autophosphorylation of human Her...
# 6       CHEMBL683802  Inhibition of autophosphorylation of human Her...
# 8       CHEMBL683802  Inhibition of autophosphorylation of human Her...
# ...              ...                                                ...
# 4040   CHEMBL5162302  Inhibition of wild type human GST-tagged HER2 ...
# 4056   CHEMBL5165276               Inhibition of ERBB2 (unknown origin)
# 4057   CHEMBL5165276               Inhibition of ERBB2 (unknown origin)
# 4058   CHEMBL5210115  Affinity Phenotypic Cellular interaction (Alam...
# 4070   CHEMBL5216307  Inhibition of HER2 (unknown origin) incubated ...
#
#      assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0             F                    None                   None  BAO_0000190
# 2             F                    None                   None  BAO_0000190
# 4             F                    None                   None  BAO_0000190
# 6             F                    None                   None  BAO_0000190
# 8             F                    None                   None  BAO_0000190
# ...         ...                     ...                    ...          ...
# 4040          B                    None                   None  BAO_0000190
# 4056          B                    None                   None  BAO_0000190
# 4057          B                    None                   None  BAO_0000190
# 4058          F                    None                   None  BAO_0000190
# 4070          B                    None                   None  BAO_0000190
#
#       ... target_organism                         target_pref_name  \
# 0     ...    Homo sapiens  Receptor protein-tyrosine kinase erbB-2
# 2     ...    Homo sapiens  Receptor protein-tyrosine kinase erbB-2
# 4     ...    Homo sapiens  Receptor protein-tyrosine kinase erbB-2
# 6     ...    Homo sapiens  Receptor protein-tyrosine kinase erbB-2
# 8     ...    Homo sapiens  Receptor protein-tyrosine kinase erbB-2
# ...   ...             ...                                      ...
# 4040  ...    Homo sapiens  Receptor protein-tyrosine kinase erbB-2
# 4056  ...    Homo sapiens  Receptor protein-tyrosine kinase erbB-2
# 4057  ...    Homo sapiens  Receptor protein-tyrosine kinase erbB-2
# 4058  ...    Homo sapiens  Receptor protein-tyrosine kinase erbB-2
# 4070  ...    Homo sapiens  Receptor protein-tyrosine kinase erbB-2
#
#      target_tax_id text_value  toid  type units    uo_units upper_value  \
# 0             9606       None  None  IC50    uM  UO_0000065        None
# 2             9606       None  None  IC50    uM  UO_0000065        None
# 4             9606       None  None  IC50    uM  UO_0000065        None
# 6             9606       None  None  IC50    uM  UO_0000065        None
# 8             9606       None  None  IC50    uM  UO_0000065        None
# ...            ...        ...   ...   ...   ...         ...         ...
# 4040          9606       None  None  IC50    nM  UO_0000065        None
# 4056          9606       None  None  IC50    uM  UO_0000065        None
# 4057          9606       None  None  IC50    uM  UO_0000065        None
# 4058          9606       None  None  IC50    nM  UO_0000065        None
# 4070          9606       None  None  IC50    nM  UO_0000065        None
#
#        value
# 0        0.3
# 2        0.4
# 4        0.1
# 6        5.0
# 8        0.1
# ...      ...
# 4040    2.55
# 4056    10.0
# 4057    10.0
# 4058  1437.0
# 4070    0.14
#
# [3576 rows x 46 columns]

# %%
activities = activities['canonical_smiles']
activities
# Out:
# 0       Cc1cc(C)c(/C=C2\C(=O)Nc3ncnc(Nc4ccc(F)c(Cl)c4)...
# 2       Cc1cc(C(=O)N2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(N...
# 4       Cc1cc(C(=O)N2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(N...
# 6       Cc1cc(C(=O)N2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(N...
# 8       Cc1cc(C(=O)NCCN2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncn...
#                               ...
# 4040    COCC(=O)NC/C=C/c1ccc2ncnc(Nc3ccc(Oc4cc5nncn5cn...
# 4056    Cc1cc(CS(=O)(=O)c2ccccc2)cc(OCc2ccc(CN3CCC[C@@...
# 4057    Cc1cc(OCc2ccc(CN3CCC[C@@H]3CO)cc2)cc(CS(=O)(=O...
# 4058    CN(C)C/C=C/C(=O)Nc1cc2c(Nc3ccc(F)c(Cl)c3)ncnc2...
# 4070           N#Cc1c(NC(=O)CNc2n[nH]c3ncccc23)sc2c1CCCC2
# Name: canonical_smiles, Length: 3576, dtype: object

# %%
print(activities.count())
# Out:
# 3576

# %%
activities.to_csv('EGFR_Data_TestFile.csv', index=True)
